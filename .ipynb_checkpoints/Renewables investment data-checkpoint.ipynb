# %% [markdown]
# Objective:
#     Data Cleansing,
#     Aggregate Data into country / year,
#     Aggregate to one investment line, not by type of investment,
#     Output data as csv

# %%
import pandas as pd
import os
import numpy as np

# %%
# Read excel file into a pandas dataframe
df = pd.read_excel ('Resources/InvestmentData.xlsx') 
df.head()
# Out:
#   Recipient Country/Area ISO-code Region  \
# 0            Afghanistan      AFG   Asia
# 1            Afghanistan      AFG   Asia
# 2            Afghanistan      AFG   Asia
# 3            Afghanistan      AFG   Asia
# 4            Afghanistan      AFG   Asia
#
#                                              Project  Year Investor  \
# 0                             ADA, MICRO HYDRO POWER  2000   Others
# 1              Afghanistan Reconstruction Trust Fund  2017   Others
# 2  Afghanistan: Emergency National Solidarity Pro...  2003      WBG
# 3  Afghanistan: Emergency National Solidarity Pro...  2005      WBG
# 4  Afghanistan: Emergency National Solidarity Pro...  2006      WBG
#
#              Technology Asset Class  Amount (USD million)  \
# 0  Renewable Hydropower       Grant              0.022474
# 1  Multiple renewables*       Grant              3.028126
# 2  Multiple renewables*       Grant             22.649842
# 3  Multiple renewables*       Grant              5.999401
# 4  Multiple renewables*       Grant              8.302498
#
#                                              Source
# 0  2000-01 OECD Credit Report System (CRS) Database
# 1     2017 OECD Credit Report System (CRS) Database
# 2  2002-03 OECD Credit Report System (CRS) Database
# 3  2004-05 OECD Credit Report System (CRS) Database
# 4     2006 OECD Credit Report System (CRS) Database

# %%
df.isnull().any()
# Out:
# Recipient Country/Area    False
# ISO-code                  False
# Region                    False
# Project                    True
# Year                      False
# Investor                  False
# Technology                False
# Asset Class               False
# Amount (USD million)      False
# Source                    False
# dtype: bool

# %%
df.count()
# Out:
# Recipient Country/Area    9275
# ISO-code                  9275
# Region                    9275
# Project                   9023
# Year                      9275
# Investor                  9275
# Technology                9275
# Asset Class               9275
# Amount (USD million)      9275
# Source                    9275
# dtype: int64

# %%
df.isnull().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9270    False
# 9271    False
# 9272    False
# 9273    False
# 9274    False
# Length: 9275, dtype: bool

# %%
df[df.isnull().any(axis=1)]
#didn't drop any NaN, because it is fine if we don't know the project name, as long there is an amount available is what we care about.
# Out:
#      Recipient Country/Area ISO-code         Region Project  Year Investor  \
# 187               Argentina      ARG  South America     NaN  2004     JICA
# 188               Argentina      ARG  South America     NaN  2005     JICA
# 189               Argentina      ARG  South America     NaN  2017     IADB
# 190               Argentina      ARG  South America     NaN  2017     IADB
# 282                 Armenia      ARM        Eurasia     NaN  2001   Others
# ...                     ...      ...            ...     ...   ...      ...
# 9188                 Zambia      ZMB         Africa     NaN  2006   Others
# 9189                 Zambia      ZMB         Africa     NaN  2014     AfDB
# 9190                 Zambia      ZMB         Africa     NaN  2017      WBG
# 9259               Zimbabwe      ZWE         Africa     NaN  2000   Others
# 9260               Zimbabwe      ZWE         Africa     NaN  2003     JICA
#
#                 Technology                               Asset Class  \
# 187   Multiple renewables*                                     Grant
# 188   Multiple renewables*                                     Grant
# 189   Multiple renewables*  Other Official Flows (non Export Credit)
# 190            Wind energy  Other Official Flows (non Export Credit)
# 282   Renewable Hydropower                                     Grant
# ...                    ...                                       ...
# 9188          Solar energy                                     Grant
# 9189  Renewable Hydropower  Other Official Flows (non Export Credit)
# 9190          Solar energy                                      Loan
# 9259  Multiple renewables*                                     Grant
# 9260  Multiple renewables*                                     Grant
#
#       Amount (USD million)                                            Source
# 187               0.016106  2004-05 OECD Credit Report System (CRS) Database
# 188               0.002169  2004-05 OECD Credit Report System (CRS) Database
# 189              60.969477     2017 OECD Credit Report System (CRS) Database
# 190              49.168933     2017 OECD Credit Report System (CRS) Database
# 282               0.342560  2000-01 OECD Credit Report System (CRS) Database
# ...                    ...                                               ...
# 9188              0.014464     2006 OECD Credit Report System (CRS) Database
# 9189             32.882806     2014 OECD Credit Report System (CRS) Database
# 9190              8.078456     2017 OECD Credit Report System (CRS) Database
# 9259              0.034433  2000-01 OECD Credit Report System (CRS) Database
# 9260              0.011236  2002-03 OECD Credit Report System (CRS) Database
#
# [252 rows x 10 columns]

# %%
df.dtypes
# Out:
# Recipient Country/Area     object
# ISO-code                   object
# Region                     object
# Project                    object
# Year                        int64
# Investor                   object
# Technology                 object
# Asset Class                object
# Amount (USD million)      float64
# Source                     object
# dtype: object

# %%
df.to_csv('Resources/InvestmentData.csv')

# %%
df.columns
# Out:
# Index(['Recipient Country/Area', 'ISO-code', 'Region', 'Project', 'Year',
#        'Investor', 'Technology', 'Asset Class', 'Amount (USD million)',
#        'Source'],
#       dtype='object')

# %%
df.drop(columns = {'Project','Investor','Source'}, inplace=True)

# %%
df
# Out:
#      Recipient Country/Area ISO-code  Region  Year            Technology  \
# 0               Afghanistan      AFG    Asia  2000  Renewable Hydropower
# 1               Afghanistan      AFG    Asia  2017  Multiple renewables*
# 2               Afghanistan      AFG    Asia  2003  Multiple renewables*
# 3               Afghanistan      AFG    Asia  2005  Multiple renewables*
# 4               Afghanistan      AFG    Asia  2006  Multiple renewables*
# ...                     ...      ...     ...   ...                   ...
# 9270               Zimbabwe      ZWE  Africa  2005          Solar energy
# 9271               Zimbabwe      ZWE  Africa  2016  Multiple renewables*
# 9272               Zimbabwe      ZWE  Africa  2017  Multiple renewables*
# 9273               Zimbabwe      ZWE  Africa  2011          Solar energy
# 9274               Zimbabwe      ZWE  Africa  2016          Solar energy
#
#      Asset Class  Amount (USD million)
# 0          Grant              0.022474
# 1          Grant              3.028126
# 2          Grant             22.649842
# 3          Grant              5.999401
# 4          Grant              8.302498
# ...          ...                   ...
# 9270       Grant              0.469651
# 9271       Grant              0.007757
# 9272       Grant              0.009594
# 9273       Grant              1.019630
# 9274       Grant              0.010000
#
# [9275 rows x 7 columns]

# %%
Countries = ["Austria","Belgium","Bulgaria",
             "Croatia","Cyprus","Czech Republic","Denmark","Estonia","Finland","France","Germany","Greece","Hungary","Ireland",
      "Italy","Latvia","Lithuania","Luxembourg","Malta","Netherlands","Poland","Portugal","Romania","Slovakia","Slovenia","Spain","Sweden","USA","UK","China","India"]

# %%
Countries_df = df[df['Recipient Country/Area'].isin(Countries)]

# %%
Countries_df
# Out:
#      Recipient Country/Area ISO-code         Region  Year  \
# 332                 Austria      AUT         Europe  2011
# 333                 Austria      AUT         Europe  2016
# 334                 Austria      AUT         Europe  2013
# 335                 Austria      AUT         Europe  2014
# 336                 Austria      AUT         Europe  2015
# ...                     ...      ...            ...   ...
# 8967                    USA      USA  North America  2013
# 8968                    USA      USA  North America  2010
# 8969                    USA      USA  North America  2012
# 8970                    USA      USA  North America  2012
# 8971                    USA      USA  North America  2011
#
#                   Technology        Asset Class  Amount (USD million)
# 332              Wind energy               Loan            234.460118
# 333              Wind energy               Loan             42.300000
# 334              Wind energy               Loan             32.165520
# 335              Wind energy               Loan             44.507679
# 336              Wind energy               Loan             27.873516
# ...                      ...                ...                   ...
# 8967  Other renewable energy  Equity Investment             35.028376
# 8968             Wind energy  Equity Investment             54.040354
# 8969             Wind energy  Equity Investment              7.523046
# 8970             Wind energy               Loan             13.595866
# 8971            Solar energy               Loan             12.235556
#
# [914 rows x 7 columns]

# %%
Countries_df['Region'].loc[Countries_df['Recipient Country/Area'] == 'UK'] = 'Great Britain'
# Out:
# /Users/ginacanales/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/ginacanales/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test_df = Countries_df.copy(deep=True)

test_df.loc[test_df['Recipient Country/Area']=='India', 'Region']='India'

test_df.Region.value_counts()
# Out:
# India            383
# Asia             240
# Europe           226
# Great Britain     59
# North America      6
# Name: Region, dtype: int64

# %%
sum_countries = test_df.replace({'Asia':'China', "North America":'USA', "Great Britain":'UK'}).groupby(['Region','Year']).sum()
# sum_countries = sum_countries.rename_axis(index={'Asia':'China'})
# sum_countries.reset_index()
sum_countries.unstack(level=0).plot(kind='line',subplots=False)
fig= plt.gcf()
fig.savefig('its_a_graph.png')

# %%
#Use GroupBy in order to aggregate the data according to the values in the country / year
#df_countries = df.groupby(['Region','Year']).sum()
#df_countries.reset_index()

# %%
import matplotlib.pyplot as plt
