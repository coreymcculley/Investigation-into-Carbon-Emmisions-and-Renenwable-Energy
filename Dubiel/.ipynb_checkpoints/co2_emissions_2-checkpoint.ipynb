# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import os
import gmaps
import requests
from pprint import pprint

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-328bc678fdf6> in <module>
#       9
#      10 # Google developer API key
# ---> 11 from config import gkey
#      12
#      13 # Configure gmaps
#
# ModuleNotFoundError: No module named 'config'

# %%
xls = pd.ExcelFile("IEA - CO2 Emissions.XLS")
df = pd.read_excel(xls, 'CO2 FC')

# %%
df
# Out:
#     CO2 emissions from fuel combustion  \
# 0                                  NaN
# 1        Back to the table of contents
# 2                million tonnes of CO2
# 3                                  NaN
# 4                                World
# ..                                 ...
# 189                            Oceania
# 190                                NaN
# 191                                NaN
# 192                                NaN
# 193                                NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                                 1971       1972       1973
# 3                                                  NaN        NaN        NaN
# 4                                              13945.2    14619.8    15460.1
# ..                                                 ...        ...        ...
# 189                                            161.117    168.056     179.32
# 190                                                NaN        NaN        NaN
# 191  The original version of this file, as publishe...        NaN        NaN
# 192  \nYou are permitted to use the data in this fi...        NaN        NaN
# 193  This notice, and any copyright or sourcing sta...        NaN        NaN
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6         Source: Unnamed: 8  \
# 0          NaN        NaN        NaN  Documentation:        NaN
# 1          NaN        NaN        NaN             NaN        NaN
# 2         1974       1975       1976            1977       1978
# 3          NaN        NaN        NaN             NaN        NaN
# 4      15426.7    15486.6    16310.2         16863.4    17363.4
# ..         ...        ...        ...             ...        ...
# 189    196.727    201.115    204.947         219.962     213.58
# 190        NaN        NaN        NaN             NaN        NaN
# 191        NaN        NaN        NaN             NaN        NaN
# 192        NaN        NaN        NaN             NaN        NaN
# 193        NaN        NaN        NaN             NaN        NaN
#
#        IEA (2019), CO2 Emissions from Fuel Combustion.  ... Unnamed: 38  \
# 0    http://wds.iea.org/wds/pdf/Worldco2_Documentat...  ...         NaN
# 1                                                  NaN  ...         NaN
# 2                                                 1979  ...        2008
# 3                                                  NaN  ...         NaN
# 4                                              17882.6  ...     29229.2
# ..                                                 ...  ...         ...
# 189                                            218.716  ...     427.362
# 190                                                NaN  ...         NaN
# 191                                                NaN  ...         NaN
# 192                                                NaN  ...         NaN
# 193                                                NaN  ...         NaN
#
#     Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2          2009        2010        2011        2012        2013        2014
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4       28845.3     30571.4     31392.6     31777.5     32362.9     32439.2
# ..          ...         ...         ...         ...         ...         ...
# 189     430.348     423.977     423.215     423.595     418.498     411.017
# 190         NaN         NaN         NaN         NaN         NaN         NaN
# 191         NaN         NaN         NaN         NaN         NaN         NaN
# 192         NaN         NaN         NaN         NaN         NaN         NaN
# 193         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 45 Unnamed: 46 Unnamed: 47
# 0           NaN         NaN         NaN
# 1           NaN         NaN         NaN
# 2          2015        2016        2017
# 3           NaN         NaN         NaN
# 4       32430.9     32413.8     32839.9
# ..          ...         ...         ...
# 189     420.878     428.616     433.457
# 190         NaN         NaN         NaN
# 191         NaN         NaN         NaN
# 192         NaN         NaN         NaN
# 193         NaN         NaN         NaN
#
# [194 rows x 48 columns]

# %%
var_row = df.iloc[2]

# %%
type(var_row)
# Out:
# pandas.core.series.Series

# %%
var_row[0]
# Out:
# 'million tonnes of CO2'

# %%
var_row = list(var_row)

# %%
print(var_row)
# Out:
# ['million tonnes of CO2', 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]

# %%
df.columns = var_row

# %%
df.head()
# Out:
#            million tonnes of CO2     1971     1972     1973     1974     1975  \
# 0                            NaN      NaN      NaN      NaN      NaN      NaN
# 1  Back to the table of contents      NaN      NaN      NaN      NaN      NaN
# 2          million tonnes of CO2     1971     1972     1973     1974     1975
# 3                            NaN      NaN      NaN      NaN      NaN      NaN
# 4                          World  13945.2  14619.8  15460.1  15426.7  15486.6
#
#       1976            1977     1978  \
# 0      NaN  Documentation:      NaN
# 1      NaN             NaN      NaN
# 2     1976            1977     1978
# 3      NaN             NaN      NaN
# 4  16310.2         16863.4  17363.4
#
#                                                 1979  ...     2008     2009  \
# 0  http://wds.iea.org/wds/pdf/Worldco2_Documentat...  ...      NaN      NaN
# 1                                                NaN  ...      NaN      NaN
# 2                                               1979  ...     2008     2009
# 3                                                NaN  ...      NaN      NaN
# 4                                            17882.6  ...  29229.2  28845.3
#
#       2010     2011     2012     2013     2014     2015     2016     2017
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2     2010     2011     2012     2013     2014     2015     2016     2017
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4  30571.4  31392.6  31777.5  32362.9  32439.2  32430.9  32413.8  32839.9
#
# [5 rows x 48 columns]

# %%
remuv_ending_rows = df.drop(df.index[190:194])
remuv_ending_rows.reset_index(drop=True)
# Out:
#              million tonnes of CO2     1971     1972     1973     1974  \
# 0                              NaN      NaN      NaN      NaN      NaN
# 1    Back to the table of contents      NaN      NaN      NaN      NaN
# 2            million tonnes of CO2     1971     1972     1973     1974
# 3                              NaN      NaN      NaN      NaN      NaN
# 4                            World  13945.2  14619.8  15460.1  15426.7
# ..                             ...      ...      ...      ...      ...
# 185                         Africa  249.199  263.999  285.663  299.444
# 186                       Americas   5081.6  5365.04  5594.44  5477.09
# 187                           Asia       ..       ..       ..       ..
# 188                         Europe       ..       ..       ..       ..
# 189                        Oceania  161.117  168.056   179.32  196.727
#
#         1975     1976            1977     1978  \
# 0        NaN      NaN  Documentation:      NaN
# 1        NaN      NaN             NaN      NaN
# 2       1975     1976            1977     1978
# 3        NaN      NaN             NaN      NaN
# 4    15486.6  16310.2         16863.4  17363.4
# ..       ...      ...             ...      ...
# 185  324.259  352.593         362.917  352.338
# 186  5293.14  5602.42         5808.41  5839.35
# 187       ..       ..              ..       ..
# 188       ..       ..              ..       ..
# 189  201.115  204.947         219.962   213.58
#
#                                                   1979  ...     2008     2009  \
# 0    http://wds.iea.org/wds/pdf/Worldco2_Documentat...  ...      NaN      NaN
# 1                                                  NaN  ...      NaN      NaN
# 2                                                 1979  ...     2008     2009
# 3                                                  NaN  ...      NaN      NaN
# 4                                              17882.6  ...  29229.2  28845.3
# ..                                                 ...  ...      ...      ...
# 185                                             369.69  ...  975.598  964.907
# 186                                            5923.06  ...  7523.86  7070.06
# 187                                                 ..  ...  13330.1  13907.9
# 188                                                 ..  ...  5869.98  5422.47
# 189                                            218.716  ...  427.362  430.348
#
#         2010     2011     2012     2013     2014     2015     2016     2017
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2       2010     2011     2012     2013     2014     2015     2016     2017
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4    30571.4  31392.6  31777.5  32362.9  32439.2  32430.9  32413.8  32839.9
# ..       ...      ...      ...      ...      ...      ...      ...      ...
#
# 1986                     object
# 1987                     object
# 1988                     object
# 1989                     object
# 1990                     object
# 1991                     object
# 1992                     object
# 1993                     object
# 1994                     object
# 1995                     object
# 1996                     object
# 1997                     object
# 1998                     object
# 1999                     object
# 2000                     object
# 2001                     object
# 2002                     object
# 2003                     object
# 2004                     object
# 2005                     object
# 2006                     object
# 2007                     object
# 2008                     object
# 2009                     object
# 2010                     object
# 2011                     object
# 2012                     object
# 2013                     object
# 2014                     object
# 2015                     object
# 2016                     object
# 2017                     object
# dtype: object

# %%
remuv_more["Country"] = remuv_more["million tonnes of CO2"]

# %%
remuv_more = remuv_more.set_index("Country")

# %%
remuv_more = remuv_more.drop(['million tonnes of CO2'], axis=1)

# %%
remuv_more.replace('..', "NaN")
# Out:
#                   1971     1972     1973     1974     1975     1976     1977  \
# Country
# Canada         340.231  357.909  375.654  385.344  377.106  389.221  401.597
# Chile          21.0364  20.6426  20.0066  19.7098  17.1117  17.8925  18.6806
# Mexico         93.7481   106.45  117.631  128.283  134.558  145.195  154.303
# United States  4289.04  4527.98  4691.09  4539.98  4355.84  4616.83  4781.62
# OECD Americas  4744.05  5012.99  5204.38  5073.32  4884.61  5169.14   5356.2
# ...                ...      ...      ...      ...      ...      ...      ...
# Africa         249.199  263.999  285.663  299.444  324.259  352.593  362.917
# Americas        5081.6  5365.04  5594.44  5477.09  5293.14  5602.42  5808.41
# Asia               NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Europe             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Oceania        161.117  168.056   179.32  196.727  201.115  204.947  219.962
#
#                   1978     1979     1980  ...     2008     2009     2010  \
# Country                                   ...
# Canada         403.136  417.314  422.262  ...  541.874  514.415  528.619
# Chile          19.3911  20.6302  21.4053  ...  66.5335  64.2128  68.6048
# Mexico         170.194  183.823  204.604  ...  434.539  425.194   440.46
# United States  4771.14  4800.31  4595.79  ...  5512.51  5120.69  5352.12
# OECD Americas  5363.86  5422.08  5244.06  ...  6555.46  6124.51   6389.8
# ...                ...      ...      ...  ...      ...      ...      ...
# Africa         352.338   369.69  397.888  ...  975.598  964.907  1017.91
# Americas       5839.35  5923.06  5750.62  ...  7523.86  7070.06   7411.5
# Asia               NaN      NaN      NaN  ...  13330.1  13907.9  14956.4
# Europe             NaN      NaN      NaN  ...  5869.98  5422.47   5641.2
# Oceania         213.58  218.716  228.353  ...  427.362  430.348  423.977
#
#                   2011     2012     2013     2014     2015     2016     2017
# Country
# Canada         541.161   539.74  549.641  555.469  557.661  548.095  547.799
# Chile          75.3167  77.2358  81.8619  75.4689  81.0922  85.2455  86.0871
# Mexico          456.46  459.456  449.627  434.204  442.417  446.176  445.992
# United States  5128.18  4903.01  5038.52  5046.56  4928.61  4838.48   4761.3
# OECD Americas  6201.12  5979.44  6119.65  6111.71  6009.78  5917.99  5841.18
# ...                ...      ...      ...      ...      ...      ...      ...
# Africa         1012.99  1070.36  1118.75  1165.58  1156.69  1165.55  1185.06
# Americas       7232.68  7073.44   7239.1  7270.14  7144.09  7017.61   6905.2
# Asia           15993.6  16565.5  17068.4  17284.2  17364.8  17439.5  17896.1
# Europe         5592.15  5549.46  5416.92  5169.52  5153.95  5130.02  5138.07
# Oceania        423.215  423.595  418.498  411.017  420.878  428.616  433.457
#
# [167 rows x 47 columns]

# %%
remuv_more = remuv_more.reset_index()

# %%
list_of_years = list(remuv_more.columns[3:50])

# %%
#list_of_countries_in_df = remuv_more['Country'].tolist()

# %%
country = []
date = []
CO2 = []

for index, row in remuv_more.iterrows():
    for i in range(3,len(row)):
        country.append(row["Country"])
        date.append(1971+i-3)
        CO2.append(row[1971+i-3])

# %%
df_dict = {
    "Country Name": country, 
    "Date": date, 
    "CO2 emissions (million tons)": CO2
}

long_df = pd.DataFrame(df_dict)

# %%
file = os.path.join("..","Source Databases","Country Codes.csv")
df_country_code = pd.read_csv(file)
df_country_code
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
#              sub-region intermediate-region  region-code  sub-region-code  \
# 0         Southern Asia                 NaN        142.0             34.0
# 1       Northern Europe                 NaN        150.0            154.0
# 2       Southern Europe                 NaN        150.0             39.0
# 3       Northern Africa                 NaN          2.0             15.0
# 4             Polynesia                 NaN          9.0             61.0
# ..                  ...                 ...          ...              ...
# 244           Polynesia                 NaN          9.0             61.0
# 245     Northern Africa                 NaN          2.0             15.0
# 246        Western Asia                 NaN        142.0            145.0
# 247  Sub-Saharan Africa      Eastern Africa          2.0            202.0
# 248  Sub-Saharan Africa      Eastern Africa          2.0            202.0
#
#      intermediate-region-code
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 244                       NaN
# 245                       NaN
# 246                       NaN
# 247                      14.0
# 248                      14.0
#
# [249 rows x 11 columns]

# %%
df_country_code = df_country_code[["name","alpha-3"]]

# %%
long_df
# Out:
#      Country Name  Date CO2 emissions (million tons)
# 0          Canada  1971                      340.231
# 1          Canada  1972                      357.909
# 2          Canada  1973                      375.654
# 3          Canada  1974                      385.344
# 4          Canada  1975                      377.106
# ...           ...   ...                          ...
# 7510      Oceania  2011                      423.215
# 7511      Oceania  2012                      423.595
# 7512      Oceania  2013                      418.498
# 7513      Oceania  2014                      411.017
# 7514      Oceania  2015                      420.878
#
# [7515 rows x 3 columns]

# %%
df_country_code = df_country_code.rename(columns={"alpha-3": "Country Code", "name": "Country Name"})
df_country_code["Lat"] = ""
df_country_code["Lng"] = ""
df_country_code
# Out:
#           Country Name Country Code Lat Lng
# 0          Afghanistan          AFG
# 1        Åland Islands          ALA
# 2              Albania          ALB
# 3              Algeria          DZA
# 4       American Samoa          ASM
# ..                 ...          ...  ..  ..
# 244  Wallis and Futuna          WLF
# 245     Western Sahara          ESH
# 246              Yemen          YEM
# 247             Zambia          ZMB
# 248           Zimbabwe          ZWE
#
# [249 rows x 4 columns]

# %%
params = {"key": gkey} 

for index, row in df_country_code.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    country = row["Country Name"]
    print(f"Searching within {country}")


    # update address key value
    params['address'] = country

    # Execute request
    country_lat_lng = requests.get(base_url, params=params)
    
    # convert response to json
    country_lat_lng = country_lat_lng.json()

    # Add resulting lat & lng to their respective columns at the current iteration's row index
    df_country_code.loc[index, "Lat"] = country_lat_lng["results"][0]["geometry"]["location"]["lat"]
    df_country_code.loc[index, "Lng"] = country_lat_lng["results"][0]["geometry"]["location"]["lng"]
# Out:
# Searching within Afghanistan
# Searching within Åland Islands
# Searching within Albania
# Searching within Algeria
# Searching within American Samoa
# Searching within Andorra
# Searching within Angola
# Searching within Anguilla
# Searching within Antarctica
# Searching within Antigua and Barbuda
# Searching within Argentina
# Searching within Armenia
# Searching within Aruba
# Searching within Australia
# Searching within Austria
# Searching within Azerbaijan
# Searching within Bahamas
# Searching within Bahrain
# Searching within Bangladesh
# Searching within Barbados
# Searching within Belarus
# Searching within Belgium
# Searching within Belize
# Searching within Benin
# Searching within Bermuda
# Searching within Bhutan
# Searching within Bolivia (Plurinational State of)
# Searching within Bonaire, Sint Eustatius and Saba
# Searching within Bosnia and Herzegovina
# Searching within Botswana
# Searching within Bouvet Island
# Searching within Brazil
# Searching within British Indian Ocean Territory
# Searching within Brunei Darussalam
# Searching within Bulgaria
# Searching within Burkina Faso
# Searching within Burundi
# Searching within Cabo Verde
# Searching within Puerto Rico
# Searching within Qatar
# Searching within Réunion
# Searching within Romania
# Searching within Russian Federation
# Searching within Rwanda
# Searching within Saint Barthélemy
# Searching within Saint Helena, Ascension and Tristan da Cunha
# Searching within Saint Kitts and Nevis
# Searching within Saint Lucia
# Searching within Saint Martin (French part)
# Searching within Saint Pierre and Miquelon
# Searching within Saint Vincent and the Grenadines
# Searching within Samoa
# Searching within San Marino
# Searching within Sao Tome and Principe
# Searching within Saudi Arabia
# Searching within Senegal
# Searching within Serbia
# Searching within Seychelles
# Searching within Sierra Leone
# Searching within Singapore
# Searching within Sint Maarten (Dutch part)
# Searching within Slovakia
# Searching within Slovenia
# Searching within Solomon Islands
# Searching within Somalia
# Searching within South Africa
# Searching within South Georgia and the South Sandwich Islands
# Searching within South Sudan
# Searching within Spain
# Searching within Sri Lanka
# Searching within Sudan
# Searching within Suriname
# Searching within Svalbard and Jan Mayen
# Searching within Sweden
# Searching within Switzerland
# Searching within Syrian Arab Republic
# Searching within Taiwan, Province of China
# Searching within Tajikistan
# Searching within Tanzania, United Republic of
# Searching within Thailand
# Searching within Timor-Leste
# Searching within Togo
# Searching within Tokelau
# Searching within Tonga
# Searching within Trinidad and Tobago
# Searching within Tunisia
# Searching within Turkey
# Searching within Turkmenistan
# Searching within Turks and Caicos Islands
# Searching within Tuvalu
# Searching within Uganda
# Searching within Ukraine
# Searching within United Arab Emirates
# Searching within United Kingdom of Great Britain and Northern Ireland
# Searching within United States of America
# Searching within United States Minor Outlying Islands
# Searching within Uruguay
# Searching within Uzbekistan
# Searching within Vanuatu
# Searching within Venezuela (Bolivarian Republic of)
# Searching within Viet Nam
# Searching within Virgin Islands (British)
# Searching within Virgin Islands (U.S.)
# Searching within Wallis and Futuna
# Searching within Western Sahara
# Searching within Yemen
# Searching within Zambia
# Searching within Zimbabwe

# %%
df_country_code
# Out:
#           Country Name Country Code      Lat      Lng
# 0          Afghanistan          AFG  33.9391    67.71
# 1        Åland Islands          ALA  60.1785  19.9156
# 2              Albania          ALB  41.1533  20.1683
# 3              Algeria          DZA  28.0339  1.65963
# 4       American Samoa          ASM  -14.271 -170.132
# ..                 ...          ...      ...      ...
# 244  Wallis and Futuna          WLF -14.2938 -178.117
# 245     Western Sahara          ESH  24.2155 -12.8858
# 246              Yemen          YEM  15.5527  48.5164
# 247             Zambia          ZMB -13.1339  27.8493
# 248           Zimbabwe          ZWE -19.0154  29.1549
#
# [249 rows x 4 columns]

# %%
merge_table = pd.merge(long_df, df_country_code, on="Country Name", how="left")
merge_table
# Out:
#      Country Name  Date CO2 emissions (million tons) Country Code      Lat  \
# 0          Canada  1971                      340.231          CAN  56.1304
# 1          Canada  1972                      357.909          CAN  56.1304
# 2          Canada  1973                      375.654          CAN  56.1304
# 3          Canada  1974                      385.344          CAN  56.1304
# 4          Canada  1975                      377.106          CAN  56.1304
# ...           ...   ...                          ...          ...      ...
# 7510      Oceania  2011                      423.215          NaN      NaN
# 7511      Oceania  2012                      423.595          NaN      NaN
# 7512      Oceania  2013                      418.498          NaN      NaN
# 7513      Oceania  2014                      411.017          NaN      NaN
# 7514      Oceania  2015                      420.878          NaN      NaN
#
#           Lng
# 0    -106.347
# 1    -106.347
# 2    -106.347
# 3    -106.347
# 4    -106.347
# ...       ...
# 7510      NaN
# 7511      NaN
# 7512      NaN
# 7513      NaN
# 7514      NaN
#
# [7515 rows x 6 columns]

# %%
merge_table_drop = merge_table.dropna()

# %%
merge_table_drop
# Out:
#      Country Name  Date CO2 emissions (million tons) Country Code      Lat  \
# 0          Canada  1971                      340.231          CAN  56.1304
# 1          Canada  1972                      357.909          CAN  56.1304
# 2          Canada  1973                      375.654          CAN  56.1304
# 3          Canada  1974                      385.344          CAN  56.1304
# 4          Canada  1975                      377.106          CAN  56.1304
# ...           ...   ...                          ...          ...      ...
# 7015        Yemen  2011                      19.8049          YEM  15.5527
# 7016        Yemen  2012                       18.119          YEM  15.5527
# 7017        Yemen  2013                      24.6485          YEM  15.5527
# 7018        Yemen  2014                      24.1503          YEM  15.5527
# 7019        Yemen  2015                      11.6621          YEM  15.5527
#
#           Lng
# 0    -106.347
# 1    -106.347
# 2    -106.347
# 3    -106.347
# 4    -106.347
# ...       ...
# 7015  48.5164
# 7016  48.5164
# 7017  48.5164
# 7018  48.5164
# 7019  48.5164
#
# [5625 rows x 6 columns]

# %%
merge_table_drop_2015 = merge_table_drop[merge_table_drop["Date"] == 2015]

# %%
problem=merge_table_drop_2015[merge_table_drop_2015["CO2 emissions (million tons)"]==".."].index
merge_table_drop_2015=merge_table_drop_2015.drop(problem)
merge_table_drop_2015["CO2 emissions (million tons)"] = merge_table_drop_2015["CO2 emissions (million tons)"].astype("float")

# %%
locations = merge_table_drop_2015[["Lat","Lng"]]
weights = merge_table_drop_2015["CO2 emissions (million tons)"].astype(float)

# create the mapping figure
fig = gmaps.figure()

# create the heatmap layer
heat_layer = gmaps.heatmap_layer(locations, weights=weights)
heat_layer.max_intensity = 100
heat_layer.point_radius = 20

# add the heatmap layer to the figure
fig.add_layer(heat_layer)

# display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
merge_table_drop.to_csv("Emissions_Lat_Lon_CountryCode.csv")

# %%
merge_table_drop = pd.read_csv("Emissions_Lat_Lon_CountryCode.csv")

# %%
merge_table_drop
# Out:
#       Unnamed: 0 Country Name  Date CO2 emissions (million tons) Country Code  \
# 0              0       Canada  1971                   340.230956          CAN
# 1              1       Canada  1972                   357.909211          CAN
# 2              2       Canada  1973                   375.653582          CAN
# 3              3       Canada  1974                   385.344416          CAN
# 4              4       Canada  1975                   377.105855          CAN
# ...          ...          ...   ...                          ...          ...
# 5620        7015        Yemen  2011                    19.804942          YEM
# 5621        7016        Yemen  2012                    18.118959          YEM
# 5622        7017        Yemen  2013                    24.648492          YEM
# 5623        7018        Yemen  2014                    24.150257          YEM
# 5624        7019        Yemen  2015                    11.662059          YEM
#
#             Lat         Lng
# 0     56.130366 -106.346771
# 1     56.130366 -106.346771
# 2     56.130366 -106.346771
# 3     56.130366 -106.346771
# 4     56.130366 -106.346771
# ...         ...         ...
# 5620  15.552727   48.516388
# 5621  15.552727   48.516388
# 5622  15.552727   48.516388
# 5623  15.552727   48.516388
# 5624  15.552727   48.516388
#
# [5625 rows x 7 columns]

# %%
merge_table_2015 = merge_table_drop[merge_table_drop["Date"]==2015]
merge_table_2015
# Out:
#       Unnamed: 0          Country Name  Date CO2 emissions (million tons)  \
# 44            44                Canada  2015                   557.660685
# 89            89                 Chile  2015                    81.092176
# 134          134                Mexico  2015                    442.41719
# 179          269             Australia  2015                   373.846773
# 224          314                Israel  2015                    63.927754
# ...          ...                   ...   ...                          ...
# 5444        6794                  Oman  2015                    63.636288
# 5489        6839                 Qatar  2015                    77.645489
# 5534        6884          Saudi Arabia  2015                   531.554326
# 5579        6974  United Arab Emirates  2015                   186.575572
# 5624        7019                 Yemen  2015                    11.662059
#
#      Country Code        Lat         Lng
# 44            CAN  56.130366 -106.346771
# 89            CHL -35.675147  -71.542969
# 134           MEX  23.634501 -102.552784
# 179           AUS -25.274398  133.775136
# 224           ISR  31.046051   34.851612
# ...           ...        ...         ...
# 5444          OMN  21.473533   55.975413
# 5489          QAT  25.354826   51.183884
# 5534          SAU  23.885942   45.079162
# 5579          ARE  23.424076   53.847818
# 5624          YEM  15.552727   48.516388
#
# [125 rows x 7 columns]

# %%
file_GDPPOPEnergy = os.path.join("..","Source Databases","GDP_POP_Energy.csv")
df_worldbank = pd.read_csv(file_GDPPOPEnergy)

# %%
df_worldbank_2015 = df_worldbank[df_worldbank["Date"] == 2015]
df_worldbank_2015.shape
# Out:
# (216, 19)

# %%
merge_co2 = pd.merge(df_worldbank_2015, merge_table_2015, on="Country Code", how="left")

# %%
merge_co2_drop = merge_co2.dropna()

# %%
merge_co2_drop["GDP"] = merge_co2_drop["GDP"].astype(float)
merge_co2_drop.sort_values(by="GDP")
# Out:
# C:\Users\cdubi\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     Country Code  Date_x           GDP  GDP Per Capita    Population  \
# 74           CUW  2015.0  3.963751e+09    26548.700004  1.579800e+05
# 187          SUR  2015.0  8.986667e+09    17349.335726  5.591430e+05
# 142          MNE  2015.0  1.016430e+10    18212.383071  6.221590e+05
# 195          TGO  2015.0  1.023289e+10     1447.229049  7.323158e+06
# 21           MLT  2015.0  1.605901e+10    38780.607116  4.450530e+05
# ..           ...     ...           ...             ...           ...
# 52           BRA  2015.0  3.014755e+12    15059.234368  2.044718e+08
# 165          RUS  2015.0  3.526236e+12    25566.287635  1.440969e+08
# 4            DEU  2015.0  3.895127e+12    51209.086462  8.168661e+07
# 110          JPN  2015.0  5.136019e+12    39672.948448  1.271410e+08
# 103          IND  2015.0  7.159798e+12     5454.347104  1.310152e+09
#
#          Country Name_x Time Code  \
# 74              Curacao    YR2015
# 187            Suriname    YR2015
# 142          Montenegro    YR2015
# 195                Togo    YR2015
# 21                Malta    YR2015
# ..                  ...       ...
# 52               Brazil    YR2015
# 165  Russian Federation    YR2015
# 4               Germany    YR2015
# 110               Japan    YR2015
# 103               India    YR2015
#
#     Access to Clean Fuels and Technologies for cooking (% of total population) [2.1_ACCESS.CFT.TOT]  \
# 74                                                  ..
# 187                                              89.26
# 142                                              68.57
# 195                                               6.24
# 21                                                 100
# ..                                                 ...
# 52                                               95.38
# 165                                              98.15
# 4                                                  100
# 110                                                100
# 103                                              39.88
#
#     Access to electricity (% of rural population with access) [1.2_ACCESS.ELECTRICITY.RURAL]  \
# 74                                                 100
# 187                                   70.8448382540775
# 142                                   99.9993237113659
# 195                                   18.6085541487546
# 21                                                 100
# ..                                                 ...
# 52                                           98.242607
# 165                                                100
# 4                                                  100
# 110                                                100
# 103                                               83.2
#
#     Access to electricity (% of total population) [1.1_ACCESS.ELECTRICITY.TOT]  \
# 74                                                 100
# 187                                   87.7446746826172
# 142                                   99.9991607666016
# 195                                   45.0285453796387
# 21                                                 100
# ..                                                 ...
# 52                                           99.710902
# 165                                                100
# 4                                                  100
# 110                                                100
# 103                                                 88
#
#      ... Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]  \
# 74   ...                                  0.347766267819474
# 187  ...                                   24.9131103610308
# 142  ...                                    43.004060548998
# 195  ...                                   71.2646671412409
# 21   ...                                   5.35500474641897
# ..   ...                                                ...
# 52   ...                                   43.7903891971588
# 165  ...                                   3.30422835092973
# 4    ...                                   14.2062526977772
# 110  ...                                   6.29735708059289
# 103  ...                                   36.0212225652817
#
#     Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]  \
# 74                                                 862
# 187                                               2258
# 142                                               3003
# 195                                                 81
# 21                                                1303
# ..                                                 ...
# 52                                              581652
# 165                                            1065623
# 4                                               640967
# 110                                            1035266
# 103                                            1383004
#
#     Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]  \
# 74                                        24714.219852
# 187                                       25154.671212
# 142                                       27696.896172
# 195                                       92564.453952
# 21                                         19161.30888
# ..                                                 ...
# 52                                       8876778.83496
# 165                                    15809140.426176
# 4                                       8327614.784616
# 110                                    10559777.562072
# 103                                    22241457.755856
#
#       UN Status Unnamed: 0      Country Name_y  Date_y  \
# 74        Other     5714.0             Curaçao  2015.0
# 187       Other     6254.0            Suriname  2015.0
# 142  Transition     2474.0          Montenegro  2015.0
# 195  Developing     4184.0                Togo  2015.0
# 21        Other     2384.0               Malta  2015.0
# ..          ...        ...                 ...     ...
# 52   Developing     5534.0              Brazil  2015.0
# 165  Transition     2609.0  Russian Federation  2015.0
# 4     Developed      854.0             Germany  2015.0
# 110   Developed      359.0               Japan  2015.0
# 103  Developing     4634.0               India  2015.0
#
#     CO2 emissions (million tons)        Lat         Lng
# 74                      4.691214  12.169570  -68.990020
# 187                     2.063356   3.919305  -56.027783
# 142                     2.358285  42.708678   19.374390
# 195                     1.906291   8.619543    0.824782
# 21                        1.6489  35.937496   14.375416
# ..                           ...        ...         ...
# 52                    453.633529 -14.235004  -51.925280
# 165                  1534.458233  61.524010  105.318756
# 4                     729.684098  51.165691   10.451526
# 110                  1155.666505  36.204824  138.252924
# 103                  2026.704698  20.593684   78.962880
#
# [120 rows x 25 columns]

# %%
plt.scatter(merge_co2_drop["CO2 emissions (million tons)"].astype(float), merge_co2_drop["GDP"].astype(float)/1000000000000, edgecolor="black", alpha=0.5)
plt.title('Countries CO2 Emissions vs. GDP, 2015')
plt.ylabel('GDP (Trillions $)')
plt.xlabel('CO2 emissions (million tons)')
plt.show()

plt.savefig("CO2EmissionsvGDPScatter.png", dpi=100)
