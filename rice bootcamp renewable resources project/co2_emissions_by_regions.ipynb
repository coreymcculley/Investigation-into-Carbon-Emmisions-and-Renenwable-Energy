# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import os

# %%
co2_data_path = "clean_co2_emissions_data.csv"
co2_data = pd.read_csv(co2_data_path)
co2_data
# Out:
#       Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0              0                 Canada  1971            340.230956
# 1              1                  Chile  1971             21.036435
# 2              2                 Mexico  1971             93.748092
# 3              3          United States  1971           4289.035482
# 4              4          OECD Americas  1971           4744.050965
# ...          ...                    ...   ...                   ...
# 7374        7374           Saudi Arabia  2017            532.181611
# 7375        7375  Syrian Arab Republic   2017             23.031045
# 7376        7376   United Arab Emirates  2017            196.510174
# 7377        7377                  Yemen  2017              8.919998
# 7378        7378            Middle East  2017           1784.974525
#
# [7379 rows x 4 columns]

# %%
middle_east_df = co2_data.loc[co2_data["Region/Country/Economy"] == "Middle East"]
middle_east_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0         156            Middle East  1971              96.36164
# 1         313            Middle East  1972            106.085546
# 2         470            Middle East  1973            123.767226
# 3         627            Middle East  1974            136.466128
# 4         784            Middle East  1975            154.869701

# %%
x_axis = middle_east_df["Year"]
middle_east_mtco2e = middle_east_df["Million tonnes of CO2"].astype(float)

plt.figure(figsize=(15,10))

plt.plot(x_axis,middle_east_mtco2e,linewidth=2,marker="",color="red")

plt.title("Total CO2 emissions contributed by the Middle East from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

output_path = os.path.join("Charts", "middleeastregionstotalco2emissions.png")
plt.savefig(output_path)
plt.show()

# %%
non_oecd_americas_df = co2_data.loc[co2_data["Region/Country/Economy"] == "Non-OECD Americas"]
non_oecd_americas_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0         143      Non-OECD Americas  1971            337.552564
# 1         300      Non-OECD Americas  1972            352.054335
# 2         457      Non-OECD Americas  1973            390.059845
# 3         614      Non-OECD Americas  1974            403.770413
# 4         771      Non-OECD Americas  1975            408.521419

# %%
x_axis = non_oecd_americas_df["Year"]
non_oecd_americas_mtco2e = non_oecd_americas_df["Million tonnes of CO2"].astype(float)

plt.figure(figsize=(15,10))

plt.plot(x_axis,non_oecd_americas_mtco2e,linewidth=2,marker="",color="orange")

plt.title("Total CO2 emissions contributed by the Non-OECD Americas from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

output_path = os.path.join("Charts", "nonamericaregionstotalco2emissions.png")
plt.savefig(output_path)
plt.show()

# %%
china_only_df = co2_data.loc[co2_data["Region/Country/Economy"] == "China (incl. Hong Kong, China)"]
china_only_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0          Region/Country/Economy  Year Million tonnes of CO2
# 0         119  China (incl. Hong Kong, China)  1971            789.414467
# 1         276  China (incl. Hong Kong, China)  1972            840.950441
# 2         433  China (incl. Hong Kong, China)  1973            873.791823
# 3         590  China (incl. Hong Kong, China)  1974             892.73758
# 4         747  China (incl. Hong Kong, China)  1975           1040.216529

# %%
x_axis = china_only_df["Year"]
china_only_mtco2e = china_only_df["Million tonnes of CO2"].astype(float)

plt.figure(figsize=(15,10))

plt.plot(x_axis,china_only_mtco2e,linewidth=2,marker="",color="yellow")

plt.title("Total CO2 emissions contributed by China from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

output_path = os.path.join("Charts", "chinaregionstotalco2emissions.png")
plt.savefig(output_path)
plt.show()

# %%
not_china_df = co2_data.loc[co2_data["Region/Country/Economy"] == "Asia (excl. China)"]
not_china_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0         116     Asia (excl. China)  1971            417.627914
# 1         273     Asia (excl. China)  1972            438.441883
# 2         430     Asia (excl. China)  1973             458.35159
# 3         587     Asia (excl. China)  1974            481.020762
# 4         744     Asia (excl. China)  1975            511.826438

# %%
x_axis = not_china_df["Year"]
not_china_mtco2e = not_china_df["Million tonnes of CO2"].astype(float)

plt.figure(figsize=(15,10))

plt.plot(x_axis,not_china_mtco2e,linewidth=2,marker="",color="green")

plt.title("Total CO2 emissions contributed by Asia (does not include China) from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

output_path = os.path.join("Charts", "notchinaregionstotalco2emissions.png")
plt.savefig(output_path)
plt.show()

# %%
africa_df = co2_data.loc[co2_data["Region/Country/Economy"] == "Africa"]
africa_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0          97                 Africa  1971            249.199196
# 1         254                 Africa  1972            263.998703
# 2         411                 Africa  1973            285.662788
# 3         568                 Africa  1974            299.443885
# 4         725                 Africa  1975            324.258552

# %%
x_axis = africa_df["Year"]
africa_mtco2e = africa_df["Million tonnes of CO2"].astype(float)

plt.figure(figsize=(15,10))

plt.plot(x_axis,africa_mtco2e,linewidth=2,marker="",color="blue")

plt.title("Total CO2 emissions contributed by Africa from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

output_path = os.path.join("Charts", "africaregionstotalco2emissions.png")
plt.savefig(output_path)
plt.show()

# %%
non_europe_eurasia_df = co2_data.loc[co2_data["Region/Country/Economy"] == "Non-OECD Europe and Eurasia"]
non_europe_eurasia_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0       Region/Country/Economy  Year Million tonnes of CO2
# 0          65  Non-OECD Europe and Eurasia  1971           2188.295908
# 1         222  Non-OECD Europe and Eurasia  1972           2307.488846
# 2         379  Non-OECD Europe and Eurasia  1973           2459.734295
# 3         536  Non-OECD Europe and Eurasia  1974           2588.506633
# 4         693  Non-OECD Europe and Eurasia  1975           2774.791211

# %%
x_axis = non_europe_eurasia_df["Year"]
non_europe_eurasia_mtco2e = non_europe_eurasia_df["Million tonnes of CO2"].astype(float)

plt.figure(figsize=(15,10))

plt.plot(x_axis,non_europe_eurasia_mtco2e,linewidth=2,marker="",color="indigo")

plt.title("Total CO2 emissions contributed by the Non-OECD Europe and Eurasia region from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

output_path = os.path.join("Charts", "noneuropestotalco2emissions.png")
plt.savefig(output_path)
plt.show()

# %%
europe_df = co2_data.loc[co2_data["Region/Country/Economy"] == "OECD Europe"]
europe_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0          38            OECD Europe  1971           3625.318567
# 1         195            OECD Europe  1972           3726.097004
# 2         352            OECD Europe  1973           3929.833365
# 3         509            OECD Europe  1974           3842.776689
# 4         666            OECD Europe  1975           3733.132336

# %%
x_axis = europe_df["Year"]
europe_mtco2e = europe_df["Million tonnes of CO2"].astype(float)

plt.figure(figsize=(15,10))

plt.plot(x_axis,europe_mtco2e,linewidth=2,marker="",color="violet")

plt.title("Total CO2 emissions contributed by the OECD Europe region from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

output_path = os.path.join("Charts", "europeregionstotalco2emissions.png")
plt.savefig(output_path)
plt.show()

# %%
oceania_df = co2_data.loc[co2_data["Region/Country/Economy"] == "OECD Asia Oceania"]
oceania_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0          10      OECD Asia Oceania  1971            974.567006
# 1         167      OECD Asia Oceania  1972           1022.017481
# 2         324      OECD Asia Oceania  1973           1156.173763
# 3         481      OECD Asia Oceania  1974           1163.464578
# 4         638      OECD Asia Oceania  1975           1139.945478

# %%
x_axis = oceania_df["Year"]
oceania_mtco2e = oceania_df["Million tonnes of CO2"].astype(float)

plt.figure(figsize=(15,10))

plt.plot(x_axis,oceania_mtco2e,linewidth=2,marker="",color="black")

plt.title("Total CO2 emissions contributed by the OECD Asia Oceania region from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

output_path = os.path.join("Charts", "oceaniaregionstotalco2emissions.png")
plt.savefig(output_path)
plt.show()

# %%
americas_df = co2_data.loc[co2_data["Region/Country/Economy"] == "OECD Americas"]
americas_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0           4          OECD Americas  1971           4744.050965
# 1         161          OECD Americas  1972           5012.985691
# 2         318          OECD Americas  1973           5204.381825
# 3         475          OECD Americas  1974            5073.31934
# 4         632          OECD Americas  1975           4884.614895

# %%
x_axis = americas_df["Year"]
americas_mtco2e = americas_df["Million tonnes of CO2"].astype(float)

plt.figure(figsize=(15,10))

plt.plot(x_axis,americas_mtco2e,linewidth=2,marker="",color="grey")

plt.title("Total CO2 emissions contributed by the OECD Americas region from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

output_path = os.path.join("Charts", "americasregionstotalco2emissions.png")
plt.savefig(output_path)
plt.show()

# %%
years = range(1970, 2017)

plt.figure(figsize=(12,12))
plt.plot(years, middle_east_mtco2e,  marker='', color='red', linewidth=3,label="Middle East")
plt.plot(years, non_oecd_americas_mtco2e, marker='', color='orange', linewidth=3,label="Non-OECD Americas")
plt.plot(years, china_only_mtco2e, marker='', color='yellow', linewidth=3,label="China")
plt.plot(years, not_china_mtco2e, marker='', color='green', linewidth=3,label="Asia (does not include China)")
plt.plot(years, africa_mtco2e, marker='', color='blue', linewidth=3,label="Africa")
plt.plot(years, non_europe_eurasia_mtco2e, marker='', color='indigo', linewidth=3,label="Non-OECD Europe and Eurasia")
plt.plot(years, europe_mtco2e, marker='', color='violet', linewidth=3,label="OECD Europe")
plt.plot(years, oceania_mtco2e, marker='', color='black', linewidth=3,label="OECD Asia Oceania")
plt.plot(years, americas_mtco2e, marker='', color='grey', linewidth=3,label="OECD Americas")
plt.legend(frameon=True, labelspacing=1, title='Regions')
plt.title("Total CO2 emissions contributed by all regions from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

output_path = os.path.join("Charts", "allregionstotalco2emissions.png")
plt.savefig(output_path)
plt.show()
