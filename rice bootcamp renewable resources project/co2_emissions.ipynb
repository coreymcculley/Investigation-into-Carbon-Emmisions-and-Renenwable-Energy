# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import os

# %%
xls = pd.ExcelFile("IEA - CO2 Emissions.XLS")
df = pd.read_excel(xls, 'CO2 FC')

# %%
df
# Out:
#     CO2 emissions from fuel combustion  \
# 0                                  NaN
# 1        Back to the table of contents
# 2                million tonnes of CO2
# 3                                  NaN
# 4                                World
# ..                                 ...
# 189                            Oceania
# 190                                NaN
# 191                                NaN
# 192                                NaN
# 193                                NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                                 1971       1972       1973
# 3                                                  NaN        NaN        NaN
# 4                                              13945.2    14619.8    15460.1
# ..                                                 ...        ...        ...
# 189                                            161.117    168.056     179.32
# 190                                                NaN        NaN        NaN
# 191  The original version of this file, as publishe...        NaN        NaN
# 192  \nYou are permitted to use the data in this fi...        NaN        NaN
# 193  This notice, and any copyright or sourcing sta...        NaN        NaN
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6         Source: Unnamed: 8  \
# 0          NaN        NaN        NaN  Documentation:        NaN
# 1          NaN        NaN        NaN             NaN        NaN
# 2         1974       1975       1976            1977       1978
# 3          NaN        NaN        NaN             NaN        NaN
# 4      15426.7    15486.6    16310.2         16863.4    17363.4
# ..         ...        ...        ...             ...        ...
# 189    196.727    201.115    204.947         219.962     213.58
# 190        NaN        NaN        NaN             NaN        NaN
# 191        NaN        NaN        NaN             NaN        NaN
# 192        NaN        NaN        NaN             NaN        NaN
# 193        NaN        NaN        NaN             NaN        NaN
#
#        IEA (2019), CO2 Emissions from Fuel Combustion.  ... Unnamed: 38  \
# 0    http://wds.iea.org/wds/pdf/Worldco2_Documentat...  ...         NaN
# 1                                                  NaN  ...         NaN
# 2                                                 1979  ...        2008
# 3                                                  NaN  ...         NaN
# 4                                              17882.6  ...     29229.2
# ..                                                 ...  ...         ...
# 189                                            218.716  ...     427.362
# 190                                                NaN  ...         NaN
# 191                                                NaN  ...         NaN
# 192                                                NaN  ...         NaN
# 193                                                NaN  ...         NaN
#
#     Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2          2009        2010        2011        2012        2013        2014
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4       28845.3     30571.4     31392.6     31777.5     32362.9     32439.2
# ..          ...         ...         ...         ...         ...         ...
# 189     430.348     423.977     423.215     423.595     418.498     411.017
# 190         NaN         NaN         NaN         NaN         NaN         NaN
# 191         NaN         NaN         NaN         NaN         NaN         NaN
# 192         NaN         NaN         NaN         NaN         NaN         NaN
# 193         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 45 Unnamed: 46 Unnamed: 47
# 0           NaN         NaN         NaN
# 1           NaN         NaN         NaN
# 2          2015        2016        2017
# 3           NaN         NaN         NaN
# 4       32430.9     32413.8     32839.9
# ..          ...         ...         ...
# 189     420.878     428.616     433.457
# 190         NaN         NaN         NaN
# 191         NaN         NaN         NaN
# 192         NaN         NaN         NaN
# 193         NaN         NaN         NaN
#
# [194 rows x 48 columns]

# %%
var_row = df.iloc[2]

# %%
type(var_row)
# Out:
# pandas.core.series.Series

# %%
var_row[0]
# Out:
# 'million tonnes of CO2'

# %%
var_row = list(var_row)

# %%
print(var_row)
# Out:
# ['million tonnes of CO2', 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]

# %%
df.columns = var_row

# %%
df.head()
# Out:
#            million tonnes of CO2     1971     1972     1973     1974     1975  \
# 0                            NaN      NaN      NaN      NaN      NaN      NaN
# 1  Back to the table of contents      NaN      NaN      NaN      NaN      NaN
# 2          million tonnes of CO2     1971     1972     1973     1974     1975
# 3                            NaN      NaN      NaN      NaN      NaN      NaN
# 4                          World  13945.2  14619.8  15460.1  15426.7  15486.6
#
#       1976            1977     1978  \
# 0      NaN  Documentation:      NaN
# 1      NaN             NaN      NaN
# 2     1976            1977     1978
# 3      NaN             NaN      NaN
# 4  16310.2         16863.4  17363.4
#
#                                                 1979  ...     2008     2009  \
# 0  http://wds.iea.org/wds/pdf/Worldco2_Documentat...  ...      NaN      NaN
# 1                                                NaN  ...      NaN      NaN
# 2                                               1979  ...     2008     2009
# 3                                                NaN  ...      NaN      NaN
# 4                                            17882.6  ...  29229.2  28845.3
#
#       2010     2011     2012     2013     2014     2015     2016     2017
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2     2010     2011     2012     2013     2014     2015     2016     2017
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4  30571.4  31392.6  31777.5  32362.9  32439.2  32430.9  32413.8  32839.9
#
# [5 rows x 48 columns]

# %%
remuv_ending_rows = df.drop(df.index[190:194])
remuv_ending_rows.reset_index(drop=True)
# Out:
#              million tonnes of CO2     1971     1972     1973     1974  \
# 0                              NaN      NaN      NaN      NaN      NaN
# 1    Back to the table of contents      NaN      NaN      NaN      NaN
# 2            million tonnes of CO2     1971     1972     1973     1974
# 3                              NaN      NaN      NaN      NaN      NaN
# 4                            World  13945.2  14619.8  15460.1  15426.7
# ..                             ...      ...      ...      ...      ...
# 185                         Africa  249.199  263.999  285.663  299.444
# 186                       Americas   5081.6  5365.04  5594.44  5477.09
# 187                           Asia       ..       ..       ..       ..
# 188                         Europe       ..       ..       ..       ..
# 189                        Oceania  161.117  168.056   179.32  196.727
#
#         1975     1976            1977     1978  \
# 0        NaN      NaN  Documentation:      NaN
# 1        NaN      NaN             NaN      NaN
# 2       1975     1976            1977     1978
# 3        NaN      NaN             NaN      NaN
# 4    15486.6  16310.2         16863.4  17363.4
# ..       ...      ...             ...      ...
# 185  324.259  352.593         362.917  352.338
# 186  5293.14  5602.42         5808.41  5839.35
# 187       ..       ..              ..       ..
# 188       ..       ..              ..       ..
# 189  201.115  204.947         219.962   213.58
#
#                                                   1979  ...     2008     2009  \
# 0    http://wds.iea.org/wds/pdf/Worldco2_Documentat...  ...      NaN      NaN
# 1                                                  NaN  ...      NaN      NaN
# 2                                                 1979  ...     2008     2009
# 3                                                  NaN  ...      NaN      NaN
# 4                                              17882.6  ...  29229.2  28845.3
# ..                                                 ...  ...      ...      ...
# 185                                             369.69  ...  975.598  964.907
# 186                                            5923.06  ...  7523.86  7070.06
# 187                                                 ..  ...  13330.1  13907.9
# 188                                                 ..  ...  5869.98  5422.47
# 189                                            218.716  ...  427.362  430.348
#
#         2010     2011     2012     2013     2014     2015     2016     2017
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2       2010     2011     2012     2013     2014     2015     2016     2017
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4    30571.4  31392.6  31777.5  32362.9  32439.2  32430.9  32413.8  32839.9
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 185  1017.91  1012.99  1070.36  1118.75  1165.58  1156.69  1165.55  1185.06
# 186   7411.5  7232.68  7073.44   7239.1  7270.14  7144.09  7017.61   6905.2
# 187  14956.4  15993.6  16565.5  17068.4  17284.2  17364.8  17439.5  17896.1
# 188   5641.2  5592.15  5549.46  5416.92  5169.52  5153.95  5130.02  5138.07
# 189  423.977  423.215  423.595  418.498  411.017  420.878  428.616  433.457
#
# [190 rows x 48 columns]

# %%
remuv_more = remuv_ending_rows.drop(remuv_ending_rows.index[0:23])
remuv_more.reset_index(drop=True)
# Out:
#     million tonnes of CO2     1971     1972     1973     1974     1975  \
# 0                  Canada  340.231  357.909  375.654  385.344  377.106
# 1                   Chile  21.0364  20.6426  20.0066  19.7098  17.1117
# 2                  Mexico  93.7481   106.45  117.631  128.283  134.558
# 3           United States  4289.04  4527.98  4691.09  4539.98  4355.84
# 4           OECD Americas  4744.05  5012.99  5204.38  5073.32  4884.61
# ..                    ...      ...      ...      ...      ...      ...
# 162                Africa  249.199  263.999  285.663  299.444  324.259
# 163              Americas   5081.6  5365.04  5594.44  5477.09  5293.14
# 164                  Asia       ..       ..       ..       ..       ..
# 165                Europe       ..       ..       ..       ..       ..
# 166               Oceania  161.117  168.056   179.32  196.727  201.115
#
#         1976     1977     1978     1979  ...     2008     2009     2010  \
# 0    389.221  401.597  403.136  417.314  ...  541.874  514.415  528.619
# 1    17.8925  18.6806  19.3911  20.6302  ...  66.5335  64.2128  68.6048
# 2    145.195  154.303  170.194  183.823  ...  434.539  425.194   440.46
# 3    4616.83  4781.62  4771.14  4800.31  ...  5512.51  5120.69  5352.12
# 4    5169.14   5356.2  5363.86  5422.08  ...  6555.46  6124.51   6389.8
# ..       ...      ...      ...      ...  ...      ...      ...      ...
# 162  352.593  362.917  352.338   369.69  ...  975.598  964.907  1017.91
# 163  5602.42  5808.41  5839.35  5923.06  ...  7523.86  7070.06   7411.5
# 164       ..       ..       ..       ..  ...  13330.1  13907.9  14956.4
# 165       ..       ..       ..       ..  ...  5869.98  5422.47   5641.2
# 166  204.947  219.962   213.58  218.716  ...  427.362  430.348  423.977
#
#         2011     2012     2013     2014     2015     2016     2017
# 0    541.161   539.74  549.641  555.469  557.661  548.095  547.799
# 1    75.3167  77.2358  81.8619  75.4689  81.0922  85.2455  86.0871
# 2     456.46  459.456  449.627  434.204  442.417  446.176  445.992
# 3    5128.18  4903.01  5038.52  5046.56  4928.61  4838.48   4761.3
# 4    6201.12  5979.44  6119.65  6111.71  6009.78  5917.99  5841.18
# ..       ...      ...      ...      ...      ...      ...      ...
# 162  1012.99  1070.36  1118.75  1165.58  1156.69  1165.55  1185.06
# 163  7232.68  7073.44   7239.1  7270.14  7144.09  7017.61   6905.2
# 164  15993.6  16565.5  17068.4  17284.2  17364.8  17439.5  17896.1
# 165  5592.15  5549.46  5416.92  5169.52  5153.95  5130.02  5138.07
# 166  423.215  423.595  418.498  411.017  420.878  428.616  433.457
#
# [167 rows x 48 columns]

# %%
rename_1st_column = remuv_more.rename(columns={"million tonnes of CO2": "Region/Country/Economy"})
rename_1st_column
# Out:
#     Region/Country/Economy     1971     1972     1973     1974     1975  \
# 23                  Canada  340.231  357.909  375.654  385.344  377.106
# 24                   Chile  21.0364  20.6426  20.0066  19.7098  17.1117
# 25                  Mexico  93.7481   106.45  117.631  128.283  134.558
# 26           United States  4289.04  4527.98  4691.09  4539.98  4355.84
# 27           OECD Americas  4744.05  5012.99  5204.38  5073.32  4884.61
# ..                     ...      ...      ...      ...      ...      ...
# 185                 Africa  249.199  263.999  285.663  299.444  324.259
# 186               Americas   5081.6  5365.04  5594.44  5477.09  5293.14
# 187                   Asia       ..       ..       ..       ..       ..
# 188                 Europe       ..       ..       ..       ..       ..
# 189                Oceania  161.117  168.056   179.32  196.727  201.115
#
#         1976     1977     1978     1979  ...     2008     2009     2010  \
# 23   389.221  401.597  403.136  417.314  ...  541.874  514.415  528.619
# 24   17.8925  18.6806  19.3911  20.6302  ...  66.5335  64.2128  68.6048
# 25   145.195  154.303  170.194  183.823  ...  434.539  425.194   440.46
# 26   4616.83  4781.62  4771.14  4800.31  ...  5512.51  5120.69  5352.12
# 27   5169.14   5356.2  5363.86  5422.08  ...  6555.46  6124.51   6389.8
# ..       ...      ...      ...      ...  ...      ...      ...      ...
# 185  352.593  362.917  352.338   369.69  ...  975.598  964.907  1017.91
# 186  5602.42  5808.41  5839.35  5923.06  ...  7523.86  7070.06   7411.5
# 187       ..       ..       ..       ..  ...  13330.1  13907.9  14956.4
# 188       ..       ..       ..       ..  ...  5869.98  5422.47   5641.2
# 189  204.947  219.962   213.58  218.716  ...  427.362  430.348  423.977
#
#         2011     2012     2013     2014     2015     2016     2017
# 23   541.161   539.74  549.641  555.469  557.661  548.095  547.799
# 24   75.3167  77.2358  81.8619  75.4689  81.0922  85.2455  86.0871
# 25    456.46  459.456  449.627  434.204  442.417  446.176  445.992
# 26   5128.18  4903.01  5038.52  5046.56  4928.61  4838.48   4761.3
# 27   6201.12  5979.44  6119.65  6111.71  6009.78  5917.99  5841.18
# ..       ...      ...      ...      ...      ...      ...      ...
# 185  1012.99  1070.36  1118.75  1165.58  1156.69  1165.55  1185.06
# 186  7232.68  7073.44   7239.1  7270.14  7144.09  7017.61   6905.2
# 187  15993.6  16565.5  17068.4  17284.2  17364.8  17439.5  17896.1
# 188  5592.15  5549.46  5416.92  5169.52  5153.95  5130.02  5138.07
# 189  423.215  423.595  418.498  411.017  420.878  428.616  433.457
#
# [167 rows x 48 columns]

# %%
final_co2_data = rename_1st_column.melt(id_vars=["Region/Country/Economy"],var_name="Year",value_name="Million tonnes of CO2")
final_co2_data
# Out:
#      Region/Country/Economy  Year Million tonnes of CO2
# 0                    Canada  1971               340.231
# 1                     Chile  1971               21.0364
# 2                    Mexico  1971               93.7481
# 3             United States  1971               4289.04
# 4             OECD Americas  1971               4744.05
# ...                     ...   ...                   ...
# 7844                 Africa  2017               1185.06
# 7845               Americas  2017                6905.2
# 7846                   Asia  2017               17896.1
# 7847                 Europe  2017               5138.07
# 7848                Oceania  2017               433.457
#
# [7849 rows x 3 columns]

# %%
final_co2_data.to_csv('co2_emissions.csv')

# %%
co2_data_path = "co2_emissions.csv"

# %%
co2_data = pd.read_csv(co2_data_path)

# %%
co2_data
# Out:
#       Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0              0                 Canada  1971            340.230956
# 1              1                  Chile  1971             21.036435
# 2              2                 Mexico  1971             93.748092
# 3              3          United States  1971           4289.035482
# 4              4          OECD Americas  1971           4744.050965
# ...          ...                    ...   ...                   ...
# 7844        7844                 Africa  2017           1185.057223
# 7845        7845               Americas  2017           6905.196047
# 7846        7846                   Asia  2017           17896.07701
# 7847        7847                 Europe  2017           5138.073041
# 7848        7848                Oceania  2017            433.456848
#
# [7849 rows x 4 columns]

# %%
#regions = ["Middle East","Non-OECD Americas","China (incl. Hong Kong, China)","Asia (excl. China)","Africa","Non-OECD Europe and Eurasia","OECD Europe","OECD Asia Oceania","OECD Americas"]

# %%
middle_east_df = co2_data.loc[co2_data["Region/Country/Economy"] == "Middle East"]
middle_east_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0         156            Middle East  1971              96.36164
# 1         323            Middle East  1972            106.085546
# 2         490            Middle East  1973            123.767226
# 3         657            Middle East  1974            136.466128
# 4         824            Middle East  1975            154.869701

# %%
x_axis = middle_east_df["Year"]
mtco2e = middle_east_df["Million tonnes of CO2"]

plt.figure(figsize=(15,10))

plt.plot(x_axis,mtco2e,linewidth=1,marker="o",color="red")

plt.title("Total CO2 emissions contributed by the Middle East from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

plt.show()

# %%
non_oecd_americas_df = co2_data.loc[co2_data["Region/Country/Economy"] == "Non-OECD Americas"]
non_oecd_americas_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0         143      Non-OECD Americas  1971            337.552564
# 1         310      Non-OECD Americas  1972            352.054335
# 2         477      Non-OECD Americas  1973            390.059845
# 3         644      Non-OECD Americas  1974            403.770413
# 4         811      Non-OECD Americas  1975            408.521419

# %%
x_axis = non_oecd_americas_df["Year"]
mtco2e = non_oecd_americas_df["Million tonnes of CO2"]

plt.figure(figsize=(15,10))

plt.plot(x_axis,mtco2e,linewidth=1,marker="o",color="blue")

plt.title("Total CO2 emissions contributed by the Non-OECD Americas from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

plt.show()

# %%
china_only_df = co2_data.loc[co2_data["Region/Country/Economy"] == "China (incl. Hong Kong, China)"]
china_only_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0          Region/Country/Economy  Year Million tonnes of CO2
# 0         119  China (incl. Hong Kong, China)  1971            789.414467
# 1         286  China (incl. Hong Kong, China)  1972            840.950441
# 2         453  China (incl. Hong Kong, China)  1973            873.791823
# 3         620  China (incl. Hong Kong, China)  1974             892.73758
# 4         787  China (incl. Hong Kong, China)  1975           1040.216529

# %%
x_axis = china_only_df["Year"]
mtco2e = china_only_df["Million tonnes of CO2"]

plt.figure(figsize=(15,10))

plt.plot(x_axis,mtco2e,linewidth=1,marker="o",color="green")

plt.title("Total CO2 emissions contributed by China from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

plt.show()

# %%
not_china_df = co2_data.loc[co2_data["Region/Country/Economy"] == "Asia (excl. China)"]
not_china_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0         116     Asia (excl. China)  1971            417.627914
# 1         283     Asia (excl. China)  1972            438.441883
# 2         450     Asia (excl. China)  1973             458.35159
# 3         617     Asia (excl. China)  1974            481.020762
# 4         784     Asia (excl. China)  1975            511.826438

# %%
x_axis = not_china_df["Year"]
mtco2e = not_china_df["Million tonnes of CO2"]

plt.figure(figsize=(15,10))

plt.plot(x_axis,mtco2e,linewidth=1,marker="o",color="orange")

plt.title("Total CO2 emissions contributed by Asia (does not include China) from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

plt.show()

# %%
africa_df = co2_data.loc[co2_data["Region/Country/Economy"] == "Africa"]
africa_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0          97                 Africa  1971            249.199196
# 1         162                 Africa  1971            249.199196
# 2         264                 Africa  1972            263.998703
# 3         329                 Africa  1972            263.998703
# 4         431                 Africa  1973            285.662788

# %%
x_axis = africa_df["Year"]
mtco2e = africa_df["Million tonnes of CO2"]

plt.figure(figsize=(15,10))

plt.plot(x_axis,mtco2e,linewidth=1,marker="o",color="purple")

plt.title("Total CO2 emissions contributed by Africa from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

plt.show()

# %%
non_europe_eurasia_df = co2_data.loc[co2_data["Region/Country/Economy"] == "Non-OECD Europe and Eurasia"]
non_europe_eurasia_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0       Region/Country/Economy  Year Million tonnes of CO2
# 0          65  Non-OECD Europe and Eurasia  1971           2188.295908
# 1         232  Non-OECD Europe and Eurasia  1972           2307.488846
# 2         399  Non-OECD Europe and Eurasia  1973           2459.734295
# 3         566  Non-OECD Europe and Eurasia  1974           2588.506633
# 4         733  Non-OECD Europe and Eurasia  1975           2774.791211

# %%
x_axis = non_europe_eurasia_df["Year"]
mtco2e = non_europe_eurasia_df["Million tonnes of CO2"]

plt.figure(figsize=(15,10))

plt.plot(x_axis,mtco2e,linewidth=1,marker="o",color="pink")

plt.title("Total CO2 emissions contributed by Non-OECD Europe and Eurasia from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

plt.show()

# %%
europe_df = co2_data.loc[co2_data["Region/Country/Economy"] == "OECD Europe"]
europe_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0          38            OECD Europe  1971           3625.318567
# 1         205            OECD Europe  1972           3726.097004
# 2         372            OECD Europe  1973           3929.833365
# 3         539            OECD Europe  1974           3842.776689
# 4         706            OECD Europe  1975           3733.132336

# %%
x_axis = europe_df["Year"]
mtco2e = europe_df["Million tonnes of CO2"]

plt.figure(figsize=(15,10))

plt.plot(x_axis,mtco2e,linewidth=1,marker="o",color="yellow")

plt.title("Total CO2 emissions contributed by OECD Europe from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

plt.show()

# %%
oceania_df = co2_data.loc[co2_data["Region/Country/Economy"] == "OECD Asia Oceania"]
oceania_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0          10      OECD Asia Oceania  1971            974.567006
# 1         177      OECD Asia Oceania  1972           1022.017481
# 2         344      OECD Asia Oceania  1973           1156.173763
# 3         511      OECD Asia Oceania  1974           1163.464578
# 4         678      OECD Asia Oceania  1975           1139.945478

# %%
x_axis = oceania_df["Year"]
mtco2e = oceania_df["Million tonnes of CO2"]

plt.figure(figsize=(15,10))

plt.plot(x_axis,mtco2e,linewidth=1,marker="o",color="black")

plt.title("Total CO2 emissions contributed by OECD Asia Oceania from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

plt.show()

# %%
americas_df = co2_data.loc[co2_data["Region/Country/Economy"] == "OECD Americas"]
americas_df.reset_index(drop=True).head()
# Out:
#    Unnamed: 0 Region/Country/Economy  Year Million tonnes of CO2
# 0           4          OECD Americas  1971           4744.050965
# 1         171          OECD Americas  1972           5012.985691
# 2         338          OECD Americas  1973           5204.381825
# 3         505          OECD Americas  1974            5073.31934
# 4         672          OECD Americas  1975           4884.614895

# %%
x_axis = americas_df["Year"]
mtco2e = americas_df["Million tonnes of CO2"]

plt.figure(figsize=(15,10))

plt.plot(x_axis,mtco2e,linewidth=1,marker="o",color="grey")

plt.title("Total CO2 emissions contributed by OECD Americas from 1971 to 2017")
plt.xlabel("Year")
plt.ylabel("Million tonnes of CO2")

plt.show()
