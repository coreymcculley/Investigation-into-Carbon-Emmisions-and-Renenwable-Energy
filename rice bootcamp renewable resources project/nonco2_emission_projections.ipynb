# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import os

# %%
nonco2_data_path = 'clean_non_co2_emissions_data.csv'
nonco2_data = pd.read_csv(nonco2_data_path)
nonco2_data
# Out:
#       Unnamed: 0      Country  Year      MtCO2e
# 0              0  Afghanistan  1990   12.003818
# 1              1      Albania  1990    4.783988
# 2              2      Algeria  1990   32.132480
# 3              3      Andorra  1990    0.022863
# 4              4       Angola  1990  128.039351
# ...          ...          ...   ...         ...
# 1750        1750    Venezuela  2030  121.206514
# 1751        1751      Vietnam  2030  134.755168
# 1752        1752        Yemen  2030   14.148266
# 1753        1753       Zambia  2030   75.679858
# 1754        1754     Zimbabwe  2030   15.368993
#
# [1755 rows x 4 columns]

# %%
list_of_developed_countries_eu = ["Austria", "Belgium", "Denmark", "Finland", "France", "Germany", "Greece", "Ireland", "Italy", "Luxembourg", "Netherlands", "Portugal", "Spain", "Sweden", "United Kingdom", 
                                  "Bulgaria", "Croatia", "Cyprus", "Czech Republic", "Estonia", "Hungary", "Latvia", "Lithuania", "Malta", "Poland", "Romania", "Slovak Republic", "Slovenia", 
                                  "Iceland", "Norway", "Switzerland"]
list_of_developed_countries_other = ["Australia", "Canada", "Japan", "New Zealand", "United States"]
list_of_developed_countries = list_of_developed_countries_eu + list_of_developed_countries_other

# %%
developed_countries = nonco2_data[nonco2_data["Country"].isin(list_of_developed_countries)]
developed_countries.reset_index(drop=True)
# Out:
#      Unnamed: 0         Country  Year       MtCO2e
# 0             8       Australia  1990   162.091288
# 1             9         Austria  1990    16.053764
# 2            16         Belgium  1990    21.001462
# 3            25        Bulgaria  1990    28.073186
# 4            31          Canada  1990   134.098506
# ..          ...             ...   ...          ...
# 310        1723           Spain  2030    81.619632
# 311        1728          Sweden  2030    13.818450
# 312        1729     Switzerland  2030     9.520652
# 313        1745  United Kingdom  2030   106.464375
# 314        1746   United States  2030  1625.177925
#
# [315 rows x 4 columns]

# %%
projectionsfor1990 = developed_countries.loc[developed_countries["Year"] == 1990]
projectionsfor1990.plot.barh(x="Country", y="MtCO2e",figsize=(15,10))

plt.title("Total Non-CO2 emissions contributed by developed countries in 2030",fontsize=18)
plt.xlabel("Metric tons of carbon dioxide equivalent",fontsize=18)
plt.ylabel("Country",fontsize=18)

plt.show()

# %%
projectionsfor1995 = developed_countries.loc[developed_countries["Year"] == 1995]
projectionsfor1995.plot.barh(x="Country", y="MtCO2e",figsize=(15,10))

plt.title("Total Non-CO2 emissions contributed by developed countries in 2030",fontsize=18)
plt.xlabel("Metric tons of carbon dioxide equivalent",fontsize=18)
plt.ylabel("Country",fontsize=18)

plt.show()

# %%
projectionsfor2000 = developed_countries.loc[developed_countries["Year"] == 2000]
projectionsfor2000.plot.barh(x="Country", y="MtCO2e",figsize=(15,10))

plt.title("Total Non-CO2 emissions contributed by developed countries in 2030",fontsize=18)
plt.xlabel("Metric tons of carbon dioxide equivalent",fontsize=18)
plt.ylabel("Country",fontsize=18)

plt.show()

# %%
projectionsfor2005 = developed_countries.loc[developed_countries["Year"] == 2005]
projectionsfor2005.plot.barh(x="Country", y="MtCO2e",figsize=(15,10))

plt.title("Total Non-CO2 emissions contributed by developed countries in 2030",fontsize=18)
plt.xlabel("Metric tons of carbon dioxide equivalent",fontsize=18)
plt.ylabel("Country",fontsize=18)

plt.show()

# %%
projectionsfor2010 = developed_countries.loc[developed_countries["Year"] == 2010]
projectionsfor2010.plot.barh(x="Country", y="MtCO2e",figsize=(15,10))

plt.title("Total Non-CO2 emissions contributed by developed countries in 2030",fontsize=18)
plt.xlabel("Metric tons of carbon dioxide equivalent",fontsize=18)
plt.ylabel("Country",fontsize=18)

plt.show()

# %%
projectionsfor2015 = developed_countries.loc[developed_countries["Year"] == 2015]
projectionsfor2015.plot.barh(x="Country", y="MtCO2e",figsize=(15,10))

plt.title("Total Non-CO2 emissions contributed by developed countries in 2030",fontsize=18)
plt.xlabel("Metric tons of carbon dioxide equivalent",fontsize=18)
plt.ylabel("Country",fontsize=18)

plt.show()

# %%
projectionsfor2020 = developed_countries.loc[developed_countries["Year"] == 2020]
projectionsfor2020.plot.barh(x="Country", y="MtCO2e",figsize=(15,10))

plt.title("Total Non-CO2 emissions contributed by developed countries in 2030",fontsize=18)
plt.xlabel("Metric tons of carbon dioxide equivalent",fontsize=18)
plt.ylabel("Country",fontsize=18)

plt.show()

# %%
projectionsfor2025 = developed_countries.loc[developed_countries["Year"] == 2025]
projectionsfor2025.plot.barh(x="Country", y="MtCO2e",figsize=(15,10))

plt.title("Total Non-CO2 emissions contributed by developed countries in 2030",fontsize=18)
plt.xlabel("Metric tons of carbon dioxide equivalent",fontsize=18)
plt.ylabel("Country",fontsize=18)

plt.show()

# %%
projectionsfor2030= developed_countries.loc[developed_countries["Year"] == 2030]
projectionsfor2030.plot.barh(x="Country", y="MtCO2e",figsize=(15,10))

plt.title("Total Non-CO2 emissions contributed by developed countries in 2030",fontsize=18)
plt.xlabel("Metric tons of carbon dioxide equivalent",fontsize=18)
plt.ylabel("Country",fontsize=18)

plt.show()
